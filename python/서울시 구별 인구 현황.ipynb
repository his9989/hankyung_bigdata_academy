# %% [markdown]
# # 서울시 구별 인구 현황
# ## 서울시 통계 DB

# %%
% matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize'] = (10,6)

# %%
population = pd.read_excel('data/OctagonExcel.xls', 
                     header=2,
                     parse_cols="B, C, D, M, N"
                    )
population.head()
# Out:
#    자치구         세대           계  세대당인구   65세이상고령자
# 0   합계  4219001.0  10158411.0   2.34  1353486.0
# 1  종로구    73668.0    164640.0   2.11    26034.0
# 2   중구    60130.0    134174.0   2.08    21249.0
# 3  용산구   107090.0    243922.0   2.14    36727.0
# 4  성동구   132415.0    312933.0   2.30    40902.0

# %%
population['자치구'].unique()
# Out:
# array(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan], dtype=object)

# %%
population = population.drop([0])
population
# Out:
#      자치구        세대         계  세대당인구  65세이상고령자
# 1    종로구   73668.0  164640.0   2.11   26034.0
# 2     중구   60130.0  134174.0   2.08   21249.0
# 3    용산구  107090.0  243922.0   2.14   36727.0
# 4    성동구  132415.0  312933.0   2.30   40902.0
# 5    광진구  160085.0  372414.0   2.23   43579.0
# 6   동대문구  160029.0  367769.0   2.20   55287.0
# 7    중랑구  179002.0  414554.0   2.29   58675.0
# 8    성북구  187822.0  458261.0   2.38   65937.0
# 9    강북구  142165.0  329042.0   2.29   56078.0
# 10   도봉구  137269.0  347338.0   2.52   52909.0
# 11   노원구  218469.0  562278.0   2.56   73588.0
# 12   은평구  202391.0  491899.0   2.41   73850.0
# 13  서대문구  137509.0  326479.0   2.28   48985.0
# 14   마포구  169626.0  387776.0   2.22   49436.0
# 15   양천구  176811.0  476627.0   2.67   54598.0
# 16   강서구  252683.0  607877.0   2.38   75046.0
# 17   구로구  171861.0  443288.0   2.40   58260.0
# 18   금천구  105862.0  253646.0   2.23   33818.0
# 19  영등포구  166733.0  401908.0   2.21   53620.0
# 20   동작구  173474.0  410703.0   2.30   56902.0
# 21   관악구  254964.0  522849.0   1.98   69486.0
# 22   서초구  173885.0  447177.0   2.55   52738.0
# 23   강남구  233583.0  565731.0   2.40   64579.0
# 24   송파구  262611.0  668366.0   2.52   75301.0
# 25   강동구  178864.0  446760.0   2.47   55902.0
# 26   NaN       NaN       NaN    NaN       NaN

# %%
population = population.drop([26])
population.tail()
# Out:
#     자치구        세대         계  세대당인구  65세이상고령자
# 21  관악구  254964.0  522849.0   1.98   69486.0
# 22  서초구  173885.0  447177.0   2.55   52738.0
# 23  강남구  233583.0  565731.0   2.40   64579.0
# 24  송파구  262611.0  668366.0   2.52   75301.0
# 25  강동구  178864.0  446760.0   2.47   55902.0

# %%
population['자치구'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
population.rename(columns = {'계':'인구수'}, inplace=True)
population.rename(columns = {'자치구':'구'}, inplace=True)
population.head()
# Out:
#      구        세대       인구수  세대당인구  65세이상고령자
# 1  종로구   73668.0  164640.0   2.11   26034.0
# 2   중구   60130.0  134174.0   2.08   21249.0
# 3  용산구  107090.0  243922.0   2.14   36727.0
# 4  성동구  132415.0  312933.0   2.30   40902.0
# 5  광진구  160085.0  372414.0   2.23   43579.0

# %%
import json
import folium
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
geo_path = 'data/skorea_municipalities_geo_simple.json'

geo_str = json.load(open(geo_path, encoding='utf-8'))
# geo_str

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['인구수']})
guDat.head()
# Out:
#      counts   gu
# 1  164640.0  종로구
# 2  134174.0   중구
# 3  243922.0  용산구
# 4  312933.0  성동구
# 5  372414.0  광진구

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='YlGnBu', #PuRd, YlGnBu
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ?map.choropleth()

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['65세이상고령자']})

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['세대당인구']})

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
population['고령비율'] = population['65세이상고령자'] / population['인구수'] * 100
population.head()
# Out:
#      구        세대       인구수  세대당인구  65세이상고령자       고령비율
# 1  종로구   73668.0  164640.0   2.11   26034.0  15.812682
# 2   중구   60130.0  134174.0   2.08   21249.0  15.836898
# 3  용산구  107090.0  243922.0   2.14   36727.0  15.056862
# 4  성동구  132415.0  312933.0   2.30   40902.0  13.070529
# 5  광진구  160085.0  372414.0   2.23   43579.0  11.701762

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['고령비율']})

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
population.sort_values(by='65세이상고령자', ascending=False).head(5)
# Out:
#       구        세대       인구수  세대당인구  65세이상고령자       고령비율
# 24  송파구  262611.0  668366.0   2.52   75301.0  11.266432
# 16  강서구  252683.0  607877.0   2.38   75046.0  12.345590
# 12  은평구  202391.0  491899.0   2.41   73850.0  15.013245
# 11  노원구  218469.0  562278.0   2.56   73588.0  13.087476
# 21  관악구  254964.0  522849.0   1.98   69486.0  13.289879

# %%
population.sort_values(by='인구수', ascending=False).head(5)
# Out:
#       구        세대       인구수  세대당인구  65세이상고령자       고령비율
# 24  송파구  262611.0  668366.0   2.52   75301.0  11.266432
# 16  강서구  252683.0  607877.0   2.38   75046.0  12.345590
# 23  강남구  233583.0  565731.0   2.40   64579.0  11.415143
# 11  노원구  218469.0  562278.0   2.56   73588.0  13.087476
# 21  관악구  254964.0  522849.0   1.98   69486.0  13.289879

# %%
population.sort_values(by='세대당인구', ascending=False).head(5)
# Out:
#       구        세대       인구수  세대당인구  65세이상고령자       고령비율
# 15  양천구  176811.0  476627.0   2.67   54598.0  11.455079
# 11  노원구  218469.0  562278.0   2.56   73588.0  13.087476
# 22  서초구  173885.0  447177.0   2.55   52738.0  11.793540
# 24  송파구  262611.0  668366.0   2.52   75301.0  11.266432
# 10  도봉구  137269.0  347338.0   2.52   52909.0  15.232713

# %%
population.sort_values(by='고령비율', ascending=False).head(5)
# Out:
#       구        세대       인구수  세대당인구  65세이상고령자       고령비율
# 9   강북구  142165.0  329042.0   2.29   56078.0  17.042809
# 2    중구   60130.0  134174.0   2.08   21249.0  15.836898
# 1   종로구   73668.0  164640.0   2.11   26034.0  15.812682
# 10  도봉구  137269.0  347338.0   2.52   52909.0  15.232713
# 3   용산구  107090.0  243922.0   2.14   36727.0  15.056862

# %%
population.to_csv('data/seoul_population.csv', sep=',', index=False, encoding='euc-kr')
