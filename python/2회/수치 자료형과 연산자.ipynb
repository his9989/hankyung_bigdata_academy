# %%
a = 10

# %%
id(a)
# Out:
# 1716740544

# %%
a = 20

# %%
id(a)
# Out:
# 1716740864

# %%
2**5
# Out:
# 32

# %%
30//7
# Out:
# 4

# %%
30%7
# Out:
# 2

# %%
43+2
# Out:
# 45

# %%
11-20
# Out:
# -9

# %%
40/4
# Out:
# 10.0

# %%
5**3
# Out:
# 125

# %%
40//8
# Out:
# 5

# %%
40//8
# Out:
# 5

# %%
40%8
# Out:
# 0

# %%
x=44

# %%
y=11

# %%
x+y
# Out:
# 55

# %%
x-y
# Out:
# 33

# %%
x*y
# Out:
# 484

# %%
x/y
# Out:
# 4.0

# %%
x**y
# Out:
# 1196683881290399744

# %%
x//y
# Out:
# 4

# %%
x%y
# Out:
# 0

# %%
a = 30
b= 50

# %%
a = a+b

# %%
a += b

# %%
a
# Out:
# 80

# %%
a=30
b=20

# %%
a%=b

# %%
print(a)
# Out:
# 1.5

# %%
3e-5
# Out:
# 3e-05

# %%
3E5
# Out:
# 300000.0

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %%
x = 5+3j

# %%
x.real
# Out:
# 5.0

# %%
x.imag
# Out:
# 3.0

# %%
a=int(5.6)

# %%
b=int(-3.5)
c=int('15')

# %%
print(a, b, c)
# Out:
# 5 -3 15

# %%
score='85'

# %%
x=float(3)

# %%
y=float(100)
z=float('15.7')

# %%
print(x, y, z)
# Out:
# 3.0 100.0 15.7

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
abs(3)
# Out:
# 3

# %%
divmod(17, 4)
# Out:
# (4, 1)

# %%
pow(2,5)
# Out:
# 32

# %% [markdown]
# ### 모듈

# %%
import math

# %%
math?
