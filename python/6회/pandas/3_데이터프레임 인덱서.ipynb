# %% [markdown]
# # 데이터프레임 인덱서

# %% [markdown]
# Pandas는 numpy 행렬과 같이 쉼표를 사용한 (행 인덱스, 열 인덱스) 형식의 인덱싱을 지원하기 위해 다음과 같은 특별한 인덱서를 제공한다.
#
# * `loc` : 라벨 기반의 복수 인덱싱
# * `iloc` : 숫자 기반의 복수 인덱싱

# %% [markdown]
# ## `loc` 인덱서

# %% [markdown]
# `loc` 인덱서는  (행 인덱스, 열 인덱스) 형식의 인덱싱을 할 수 있지만 행/열 인덱서들이 모두 다음 중 하나이어야 한다.
#
# * 정수 인덱스가 아닌 **라벨 값(원래가 정수 인덱스인 경우는 예외)**
# * 라벨 값의 리스트
# * 라벨 값의 슬라이싱
# * 불리언 리스트, 1차원 배열, 시리즈 (**데이터프레임은 안된다.**)
# * 또는 데이터프레임을 입력으로 받고 위의 값을 반환하는 함수

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.arange(10, 22).reshape(3, 4),
                  index=["a", "b", "c"],
                  columns=["A", "B", "C", "D"])
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df=pd.DataFrame(np.arange(10, 22).reshape(3, 4),
               index=["a", "b", "c"],
               columns=["A", "B", "C", "D"])
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc["a", "A"]
# Out:
# 10

# %%
df.loc["b":, "A"]
# Out:
# b    14
# c    18
# Name: A, dtype: int32

# %%
df.loc["a", :]
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %%
df.loc[["a", "b"], ["B", "D"]]
# Out:
#     B   D
# a  11  13
# b  15  17

# %%
df.loc[df.A > 10, :]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# `loc` 인덱서를 사용하면 하나의 행을 시리즈 자료형으로 뽑아낼 수 있다. 만약  `loc` 인덱서를 사용하지 않으면 슬라이싱을 해야 하는데 이 경우에는 데이터프레임 자료형을 반환한다.

# %%
df.loc["a", :] #df.loc['a']
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %%
df[:1]  # loc 인덱서를 사용하지 않는 경우 데이터 프레임으로 출력
# Out:
#     A   B   C   D
# a  10  11  12  13

# %%
# df.loc[:, df[:1] <= 11]  # 데이터프레임은 loc 인덱서에 넣을 수 없으므로 에러!
df.loc[:, df.loc["a", :] <= 11] # 이렇게 해야 한다.
# Out:
#     A   B
# a  10  11
# b  14  15
# c  18  19

# %%
def find_rows(df):
    return df.A > 12

# %%
find_rows(df)
# Out:
# a    False
# b     True
# c     True
# e     True
# Name: A, dtype: bool

# %%
df.loc[find_rows(df), ["C"]]
# Out:
#     C
# b  16
# c  20
# e  92

# %% [markdown]
# 만약 `loc` 인덱서를 사용하면서 인덱스를 하나만 넣을 경우에는 행(row)을 선택한다.

# %%
df.loc["a"]
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int64

# %%
df.loc["e"] = [90, 91, 92, 93]
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21
# e  90  91  92  93

# %% [markdown]
# ## `iloc` 인덱서

# %% [markdown]
# `iloc` 인덱서는 `loc` 인덱서와 반대로 라벨이 아닌 정수 인덱스만 받는다.

# %%
df.iloc[0, 1]
# Out:
# 11

# %%
df.iloc[:2, 2]
# Out:
# a    12
# b    16
# Name: C, dtype: int64

# %%
df.iloc[0, -2:]
# Out:
# C    12
# D    13
# Name: a, dtype: int64

# %%
df.iloc[2:3, 1:3]
# Out:
#     B   C
# c  19  20

# %% [markdown]
# `loc` 인덱서와 마찬가지로 인덱스가 하나만 들어가면 행을 선택한다.

# %%
df.iloc[-1]
# Out:
# A    90
# B    91
# C    92
# D    93
# Name: e, dtype: int64

# %%
df.iloc[-1] = df.iloc[-1] * 4
df
# Out:
#      A    B    C    D
# a   10   11   12   13
# b   14   15   16   17
# c   18   19   20   21
# e  720  728  736  744

# %% [markdown]
# #### 연습 문제 1
#
# 1. 모든 행과 열에 라벨을 가지는 5 x 5 이상의 크기를 가지는 데이터프레임을 만든다.
# 2. 10가지 이상의 방법으로 특정한 행과 열을 선택한다.

# %%
data=pd.read_csv("crime_in_Seoul.csv",  engine='python')

# %%
data['살인 발생']
# Out:
# 0      2
# 1      3
# 2      1
# 3      2
# 4      3
# 5      5
# 6      2
# 7      5
# 8      8
# 9     14
# 10     4
# 11     5
# 12     4
# 13     2
# 14     7
# 15     3
# 16    13
# 17     3
# 18     9
# 19     7
# 20     4
# 21     3
# 22     8
# 23     7
# 24     3
# 25    11
# 26    10
# 27     1
# 28     1
# 29     3
# 30    10
# Name: 살인 발생, dtype: int64

# %%
data.loc[:, '살인 발생']
# Out:
# 0      2
# 1      3
# 2      1
# 3      2
# 4      3
# 5      5
# 6      2
# 7      5
# 8      8
# 9     14
# 10     4
# 11     5
# 12     4
# 13     2
# 14     7
# 15     3
# 16    13
# 17     3
# 18     9
# 19     7
# 20     4
# 21     3
# 22     8
# 23     7
# 24     3
# 25    11
# 26    10
# 27     1
# 28     1
# 29     3
# 30    10
# Name: 살인 발생, dtype: int64

# %%
data.iloc[13:32]
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 13  서부서      2      2      2      1     70     59    819    293  1,192  1,038
# 14  강북서      7      8     14     13    153    126  1,434    618  2,649  2,348
# 15  금천서      3      4      6      6    151    122  1,567    888  2,054  1,776
# 16  중랑서     13     12     11      9    187    148  2,135    829  2,847  2,407
# 17  강남서      3      3     15     12    300    225  2,411    984  2,465  2,146
# 18  관악서      9      8     12     14    320    221  2,706    827  3,298  2,642
# 19  강서서      7      8     13     13    262    191  2,096  1,260  3,207  2,718
# 20  강동서      4      3      6      8    156    123  2,366    789  2,712  2,248
# 21  종암서      3      3      3      3     64     53    832    332  1,015    840
# 22  구로서      8      6     15     11    281    164  2,335    889  3,007  2,432
# 23  서초서      7      4      8      5    334    193  1,982    905  1,852  1,607
# ...

# %%
data.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
data['살인검거률']=data['살인 검거'] / data['살인 발생'] * 100
data['범죄발생건수']=data['살인 발생']+data['강도 발생']+data['강간 발생']#+data['절도 발생']#+data['폭력 발생']
data
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278
# 2   남대문서      1      0      6      4     65     46  1,153    382    869
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050
# 6    성북서      2      2      2      1     86     71    953    409  1,194
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612
# 11   동작서      5      5      9      5    285    139  1,865    661  1,910
# ...

# %%
data.loc[:]
# Out:
#      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278
# 2   남대문서      1      0      6      4     65     46  1,153    382    869
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050
# 6    성북서      2      2      2      1     86     71    953    409  1,194
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612
# 11   동작서      5      5      9      5    285    139  1,865    661  1,910
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 0    중부서      2      2      3      2    105     65  1,395    477  1,355
# 1    종로서      3      3      6      5    115     98  1,070    413  1,278
# 2   남대문서      1      0      6      4     65     46  1,153    382    869
# 3   서대문서      2      2      5      4    154    124  1,812    738  2,056
# 4    혜화서      3      2      5      4     96     63  1,114    424  1,015
# 5    용산서      5      5     14     14    194    173  1,557    587  2,050
# 6    성북서      2      2      2      1     86     71    953    409  1,194
# 7   동대문서      5      5     13     13    173    146  1,981    814  2,548
# 8    마포서      8      8     14     10    294    247  2,555    813  2,983
# 9   영등포서     14     12     22     20    295    183  2,964    978  3,572
# 10   성동서      4      4      9      8    126    119  1,607    597  1,612
# 11   동작서      5      5      9      5    285    139  1,865    661  1,910
# ...
