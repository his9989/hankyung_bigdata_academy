# %% [markdown]
# # 영어 워드클라우드

# %%
# 모듈 불러오기
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from wordcloud import WordCloud
from wordcloud import STOPWORDS
# %matplotlib inline

# 파일 입력
text = open('alice.txt').read()
mask_image = np.array(Image.open('alice_color.png'))

# 워드 클라우드에서 지우고 싶은 단어
stopwords =set(STOPWORDS)
# stopwords.add('지우고 싶은 stopword')

# wordcloud 생성
wordcolud_3 = WordCloud(background_color='white', max_words=2000, mask=mask_image, 
                       stopwords = stopwords, max_font_size=40, random_state=42)

wordcolud_3.generate(text)

# 디자인 사진 색 안살려서 wordcloud
# plt.imshow(wordcolud_3)


#  원본 사진 색 살려서
from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(mask_image)

# 원본 사진 색 살려서
plt.imshow(wordcolud_3.recolor(color_func=image_colors))

# %% [markdown]
# # konlpy

# %%
   # 모듈 임포트
import nltk
from konlpy.tag import Twitter

#트위터 형태소분석기 tw 변수에 할당
tw = Twitter()

# text 변수에 텍스트 할당
text= open('bitcoin_news.txt').read()

# text 변수 명사 추출 후 nouns 변수에 할당
nouns = tw.nouns(text)

# 빼고싶은 stopwords 추가
# stop_words = ['가','나','다']
# nouns = [word for word in nouns if word not in stop_words]

# text에서 추출한 nouns 변수 빈도수 수치화
nltk_text = nltk.Text(nouns) 
data = nltk_text.vocab().most_common(200) # 상위 200개 , 수정 가능
data = dict(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-50cd17f6462c> in <module>()
#       7
#       8 # text 변수에 텍스트 할당
# ----> 9 text= open('twitter.txt').read()
#      10
#      11 # text 변수 명사 추출 후 nouns 변수에 할당
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xbf in position 2: illegal multibyte sequence

# %% [markdown]
# # konlpy + 한글 워드클라우드

# %%
# 모듈 임포트
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from wordcloud import WordCloud
from wordcloud import STOPWORDS
# %matplotlib inline

import nltk
from konlpy.tag import Twitter

#트위터 형태소분석기 tw 변수에 할당
tw = Twitter()

# text 변수에 텍스트 할당
text= open('bitcoin_news.txt').read()

# text 변수 명사 추출 후 nouns 변수에 할당
nouns = tw.nouns(text)

# # 빼고싶은 stopwords 추가
# stop_words = []
# nouns = [word for word in nouns if word not in stop_words]

# text에서 추출한 nouns 변수 빈도수 수치화
nltk_text = nltk.Text(nouns) 
data = nltk_text.vocab().most_common(200) # 상위 200개 , 수정 가능
data = dict(data)

# 시각화

# 디자인 이미지 파일 로드
mask_image = np.array(Image.open('bitcoin.png'))

# 워드클라우드 그림 그리기
wordcolud_3 = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                        background_color='white', 
                        max_words=3000, 
                        mask=mask_image, 
                        # stopwords = stopwords, 
                        max_font_size=50, 
                        min_font_size=1, 
                        relative_scaling = 0.3, 
                        random_state=42)

# 영어 데이터는 .generate(data)로 하면 한 번에 해결 되지만 한글은 안됨
# 그래서 위에서 자연어 처리한 결과 값을 .generate_fro_frequencies(data) 로 
wordcolud_3.generate_from_frequencies(data)

from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(mask_image)


# 원본 사진 색 살려서
plt.figure(figsize=(12,12))
plt.imshow(wordcolud_3)
# plt.imshow(wordcolud_3.recolor(color_func=image_colors))
plt.axis('off')
plt.show()

# %%
text
